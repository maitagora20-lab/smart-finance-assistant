# %% [markdown]
# <a href="https://colab.research.google.com/github/maitagora20-lab/smart-finance-assistant/blob/main/Maita's_Diary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Project Overview
#
# I plan to develop a Python-based Smart Finance Assistant application that assists users with their personal finance activities by improving their management capabilities. The financial data will be read from CSV files to study spending habits and deliver basic recommendations. The system will use a custom decision-making tool that includes a savings calculator and currency converter. Google Colab will serve as the application's development platform, and I’ll use a six-step development process, which begins with problem understanding and ends with final solution testing.
#
# Planned Approach
#
# I will begin the development process by identifying the financial problem and specifying all required inputs and outputs. I will explain the system's behaviour through direct manual examples that demonstrate expected results and plan the system’s logic using pseudocode, which will later be translated into Python code. The coding phase will focus on implementing key features, including CSV data processing, financial analysis, and a custom tool.
#
# Use of Artificial Intelligence
#
# The AI system will create initial code structures, which developers will improve by using AI suggestions to identify and fix errors. All AI-generated content will undergo a thorough review process, including testing and necessary modifications to verify its accuracy and ensure understanding. I will document my weekly AI usage through screenshots of my AI interactions, a description of the reasons for our AI usage, and an effectiveness evaluation and improvement assessment. This will demonstrate my regular use of AI as a development tool rather than using it unthinkingly.
#
# Overall, the project aims to enhance my technical abilities and problem-solving skills.
